# %%
import pandas as pd
# # add try accept here, test?
# oh yah, so I can create a test function ensuring the that file is present?
# can I create a test that will assert the file is of type. csv?
# Create a variable for the file path
#filename = 2019-2020.CLEANED.NHLStatsPersonalLapTopCopy.xlsx
#file patch = C:/Users/jpkee/Documents/My Tableau Repository/Datasources
# nbaStats = pd.read_csv("C:/Users/jpkee/Desktop/PythonProjects/NBA 2018-19 Season.csv")
nhlStats = pd.read_excel("C:/Users/jpkee/Documents/My Tableau Repository/Datasources/2019-2020.CLEANED.NHLStatsPersonalLapTopCopy.xlsx")

nhlStats.shape
# Out:
# (883, 26)

# %%
nhlStats.head()
# Out:
#     Rk             Player  Age   Tm Pos  GP    CF    CA   CF%  CF% rel  ...  \
# 0  289  Zemgus Girgensons   26  BUF   C  69   605   634  48.8     -0.7  ...
# 1  132        Zdeno Chara   42  BOS   D  68  1012  1164  46.5     -6.5  ...
# 2  754         Zack Smith   31  CHI   C  50   406   487  45.5     -4.1  ...
# 3  513       Zack MacEwen   23  VAN   C  17   135   180  42.9     -4.2  ...
# 4  420       Zack Kassian   29  EDM  RW  59   810   873  48.1      1.2  ...
#
#      PDO  oZS%  dZS%    TOI/60   TOI(EV)  TK  GV  E+/-  SAtt. Thru%
# 0  100.4  38.1  61.9  13:48:00  11:36:00  13  11  -4.5    144  59.0
# 1  104.8  35.7  64.3  21:01:00  17:27:00  26  52  -4.6    155  55.5
# 2  102.3  41.5  58.5  11:47:00  10:21:00  21  14  -5.7     76  56.6
# 3  111.5  46.3  53.7  09:37:00  09:14:00   4   8  -2.2     31  54.8
# 4  101.0  54.8  45.2  15:40:00  15:10:00  26  45   3.0    164  60.4
#
# [5 rows x 26 columns]

# %%
nhlStats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 883 entries, 0 to 882
# Data columns (total 26 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Rk       883 non-null    int64
#  1   Player   883 non-null    object
#  2   Age      883 non-null    int64
#  3   Tm       883 non-null    object
#  4   Pos      883 non-null    object
#  5   GP       883 non-null    int64
#  6   CF       883 non-null    int64
#  7   CA       883 non-null    int64
#  8   CF%      883 non-null    float64
#  9   CF% rel  883 non-null    float64
#  10  FF       883 non-null    int64
#  11  FA       883 non-null    int64
#  12  FF%      883 non-null    float64
#  13  FF% rel  883 non-null    float64
#  14  oiSH%    879 non-null    float64
#  15  oiSV%    882 non-null    float64
#  16  PDO      878 non-null    float64
#  17  oZS%     882 non-null    float64
#  18  dZS%     882 non-null    float64
#  19  TOI/60   883 non-null    object
# ...

# %%
# grab a couple columns
# per https://data36.com/pandas-tutorial-1-basics-reading-data-files-dataframes-data-selection/
# the outer bracket frames tell pandas that you want to select columns, 
# and the inner brackets are for the list of the column names.
nhlStats[['Rk', 'Player']]
# Out:
#       Rk             Player
# 0    289  Zemgus Girgensons
# 1    132        Zdeno Chara
# 2    754         Zack Smith
# 3    513       Zack MacEwen
# 4    420       Zack Kassian
# ..   ...                ...
# 878  233          Adam Erne
# 879   96        Adam Brooks
# 880   77       Adam Boqvist
# 881  584         Aaron Ness
# 882  221       Aaron Ekblad
#
# [883 rows x 2 columns]

# %%
nhlStats.sample(3)
# Out:
#       Rk             Player  Age   Tm Pos  GP    CF    CA   CF%  CF% rel  ...  \
# 285  726  Mikhail Sergachev   21  TBL   D  70  1177  1046  52.9      1.3  ...
# 95   359        Taro Hirose   23  DET  LW  26   201   255  44.1     -3.6  ...
# 178  168      Rasmus Dahlin   19  BUF   D  59   889   829  51.7      4.0  ...
#
#        PDO  oZS%  dZS%    TOI/60   TOI(EV)  TK  GV  E+/-  SAtt. Thru%
# 285  101.5  54.7  45.3  20:22:00  17:01:00  18  39   5.7    274  43.1
# 95    93.4  49.2  50.8  12:33:00  10:04:00   6  20  -5.2     39  53.8
# 178   99.6  58.9  41.1  19:18:00  15:49:00  16  42  -5.5    219  41.1
#
# [3 rows x 26 columns]

# %%
nhlStats.loc[:, ['GP']].median()
# Out:
# GP    53.0
# dtype: float64

# %%
nhlStats.loc[:, ['Age']].median()
# Out:
# Age    26.0
# dtype: float64

# %%
nhlStats.loc[:, ['CF']].median()
# Out:
# CF    588.0
# dtype: float64

# %%
nhlStats.describe()
# Out:
#                Rk         Age          GP           CF           CA  \
# count  883.000000  883.000000  883.000000   883.000000   883.000000
# mean   442.000000   26.171008   44.109853   576.941110   575.185730
# std    255.044441    4.054780   24.447647   395.987687   376.120906
# min      1.000000   18.000000    1.000000     1.000000     0.000000
# 25%    221.500000   23.000000   20.000000   190.500000   191.500000
# 50%    442.000000   26.000000   53.000000   588.000000   625.000000
# 75%    662.500000   29.000000   66.000000   905.500000   861.500000
# max    883.000000   42.000000   71.000000  1587.000000  1557.000000
#
#               CF%     CF% rel           FF           FA         FF%  ...  \
# count  883.000000  883.000000   883.000000   883.000000  883.000000  ...
# mean    48.923103   -1.067837   434.800680   433.612684   48.978029  ...
# std      6.300276    6.267539   298.839351   285.411382    6.515190  ...
# ...

# %%
#swap for a different dataset

# %%
# NHLStats.V2
nhlStatsV2 = pd.read_excel("C:/Users/jpkee/Documents/My Tableau Repository/Datasources/NHLStats.V2.xlsx")
nhlStatsV2.head(3)
# Out:
#    Rk             Player  Age   Tm Pos  GP  G  A  PTS  +/-  ...  SH.1   S  \
# 0   1  Justin Abdelkader   32  DET  LW  49  0  3    3  -14  ...     0  40
# 1   2       Pontus Aberg   26  TOR  LW   5  0  1    1    0  ...     0   4
# 2   3     Vitaly Abramov   21  OTT  RW   2  1  0    1    0  ...     0   3
#
#      S%  TOI      ATOI  BLK  HIT  FOW  FOL   FO%
# 0   0.0  565  11:32:00   26  103   38   31  55.1
# 1   0.0   44  08:42:00    1    1    0    0   NaN
# 2  33.3   12  05:47:00    0    0    0    0   NaN
#
# [3 rows x 28 columns]

# %%
# get player name and age
# using the loc bit
nhlStatsV2.shape
# Out:
# (1016, 28)

# %%
nhlStatsV2.sort_values(by=['TOI'], ascending=False)
# Out:
#       Rk           Player  Age   Tm Pos  GP   G   A  PTS  +/-  ...  SH.1    S  \
# 137  130    Thomas Chabot   23  OTT   D  71   6  33   39  -18  ...     0  186
# 468  403       Roman Josi   29  NSH   D  69  16  49   65   22  ...     0  260
# 113  106      Brent Burns   34  SJS   D  70  12  33   45  -22  ...     1  225
# 221  198     Drew Doughty   30  LAK   D  67   7  28   35  -16  ...     1  141
# 748  655    Ivan Provorov   23  PHI   D  69  13  23   36   11  ...     1  150
# ..   ...              ...  ...  ...  ..  ..  ..  ..  ...  ...  ...   ...  ...
# 120  113       Paul Carey   31  BOS   C   1   0   0    0   -1  ...     0    0
# 905  785       C.J. Suess   25  WPG  LW   1   0   0    0   -1  ...     0    0
# 765  670  Anthony Richard   23  NSH   C   1   0   0    0   -1  ...     0    2
# 808  707   Ashton Sautner   25  VAN   D   1   0   0    0    0  ...     0    1
# 868  750     Dalton Smith   27  BUF  LW   1   0   0    0    1  ...     0    0
#
# ...

# %%
nhlStatsV2.sort_values(by=['HIT', 'BLK'], ascending=False)
# Out:
#       Rk           Player  Age   Tm Pos  GP   G   A  PTS  +/-  ...  SH.1    S  \
# 760  667      Ryan Reaves   33  VEG  RW  71   8   7   15   -5  ...     0   61
# 937  813    Brady Tkachuk   20  OTT  LW  71  21  23   44  -14  ...     0  259
# 997  867       Tom Wilson   25  WSH  RW  68  21  23   44   -3  ...     1  154
# 914  794    Brandon Tanev   28  PIT  LW  68  11  14   25   -1  ...     1   95
# 609  533      Matt Martin   30  NYI  LW  55   5   3    8   -1  ...     0   49
# ..   ...              ...  ...  ...  ..  ..  ..  ..  ...  ...  ...   ...  ...
# 741  648  Austin Poganski   23  STL  RW   1   0   0    0    0  ...     0    0
# 765  670  Anthony Richard   23  NSH   C   1   0   0    0   -1  ...     0    2
# 808  707   Ashton Sautner   25  VAN   D   1   0   0    0    0  ...     0    1
# 868  750     Dalton Smith   27  BUF  LW   1   0   0    0    1  ...     0    0
# 935  811    Conor Timmins   21  COL   D   2   0   0    0    2  ...     0    1
#
# ...

# %%
nhlStatsV2.sort_values(by=['BLK', 'HIT'], ascending=False)
# Out:
#       Rk           Player  Age   Tm Pos  GP  G   A  PTS  +/-  ...  SH.1    S  \
# 501  432    Oscar Klefbom   26  EDM   D  62  5  29   34  -17  ...     0  159
# 809  708     David Savard   29  CBJ   D  68  0  11   11   -3  ...     0   97
# 241  216  Alexander Edler   33  VAN   D  59  5  28   33   13  ...     0  118
# 915  795      Chris Tanev   30  VAN   D  69  2  18   20    4  ...     1   45
# 354  307      Andy Greene   37  TOT   D  63  2  12   14    1  ...     2   60
# ..   ...              ...  ...  ...  ..  .. ..  ..  ...  ...  ...   ...  ...
# 741  648  Austin Poganski   23  STL  RW   1  0   0    0    0  ...     0    0
# 765  670  Anthony Richard   23  NSH   C   1  0   0    0   -1  ...     0    2
# 808  707   Ashton Sautner   25  VAN   D   1  0   0    0    0  ...     0    1
# 868  750     Dalton Smith   27  BUF  LW   1  0   0    0    1  ...     0    0
# 935  811    Conor Timmins   21  COL   D   2  0   0    0    2  ...     0    1
#
# ...

# %%
# Now create a viz of goals by player
# use matplotlib
import matplotlib.pyplot as plt
# now get the data 
# 'nhlStatsV2' is the name of the data
# nhlStatsV2.info
# nhlStatsV2.info()
# remember to use the () here
# working off of https://towardsdatascience.com/data-visualization-exploration-using-pandas-only-beginner-a0a52eb723d5

# another way to check for nulls
pd.isnull(nhlStatsV2).any()
# ok so this are nulls
# Out:
# Rk        False
# Player    False
# Age       False
# Tm        False
# Pos       False
# GP        False
# G         False
# A         False
# PTS       False
# +/-       False
# PIM       False
# PS        False
# EV        False
# PP        False
# SH        False
# GW        False
# EV.1      False
# PP.1      False
# SH.1      False
# S         False
# S%         True
# TOI       False
# ATOI      False
# BLK       False
# HIT       False
# FOW       False
# FOL       False
# FO%        True
# dtype: bool

# %%
topGoals=nhlStatsV2.groupby('Player')[['PTS']].count()
topGoals
# Out:
#                    PTS
# Player
# Aaron Ekblad         1
# Aaron Ness           1
# Adam Boqvist         1
# Adam Brooks          1
# Adam Erne            1
# ...                ...
# Zack Kassian         1
# Zack MacEwen         1
# Zack Smith           1
# Zdeno Chara          1
# Zemgus Girgensons    1
#
# [883 rows x 1 columns]

# %% [markdown]
# ![image.png](attachment:image.png)
