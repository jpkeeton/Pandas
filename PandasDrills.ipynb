# %%
import pandas as pd 
# Read data from file 'filename.csv' 
nbaStats = pd.read_csv("NBA 2018-19 Season.csv") 
# Preview the first 5 lines of the loaded data 
nbaStats.head(1000)
# or we can get a sample of rows w this command
# nbaStats.sample(5)
# Out:
#     Conference   Division              Team                Player  Age  Games  \
# 0      Eastern   Atlantic    Boston Celtics          Jayson Tatum   20     79
# 1      Eastern   Atlantic    Boston Celtics          Kyrie Irving   26     67
# 2      Eastern   Atlantic    Boston Celtics          Marcus Smart   24     80
# 3      Eastern   Atlantic    Boston Celtics         Marcus Morris   29     75
# 4      Eastern   Atlantic    Boston Celtics            Al Horford   32     68
# ..         ...        ...               ...                   ...  ...    ...
# 617    Western  Southwest  Dallas Mavericks           Salah Mejri   32     36
# 618    Western  Southwest  Dallas Mavericks          Courtney Lee   33     22
# 619    Western  Southwest  Dallas Mavericks           Daryl Macon   23      8
# 620    Western  Southwest  Dallas Mavericks  Kostas Antetokounmpo   21      2
# 621    Western  Southwest  Dallas Mavericks          Ray Spalding   21      1
#
# ...

# %%
nbaStats.index
# Out:
# RangeIndex(start=0, stop=622, step=1)

# %%
# now let's get the shape
nbaStats.shape
# Out:
# (622, 30)

# %%
# .info is super useful too
nbaStats.info()
#try it with and w/o the '()'
# is it like pivoting?
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 622 entries, 0 to 621
# Data columns (total 30 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Conference                       622 non-null    object
#  1   Division                         622 non-null    object
#  2   Team                             622 non-null    object
#  3   Player                           622 non-null    object
#  4   Age                              622 non-null    int64
#  5   Games                            622 non-null    int64
#  6   Games Started                    622 non-null    int64
#  7   Minutes Played                   622 non-null    int64
#  8   Field Goals                      622 non-null    int64
#  9   Field Goal Attempts              622 non-null    int64
#  10  Field Goal Percentage            616 non-null    float64
#  11  3-Point Field Goals              622 non-null    int64
# ...

# %%
# grab a couple columns
# per https://data36.com/pandas-tutorial-1-basics-reading-data-files-dataframes-data-selection/
# the outer bracket frames tell pandas that you want to select columns, 
# and the inner brackets are for the list of the column names.
nbaStats[['Division', 'Team']]
# Out:
#       Division              Team
# 0     Atlantic    Boston Celtics
# 1     Atlantic    Boston Celtics
# 2     Atlantic    Boston Celtics
# 3     Atlantic    Boston Celtics
# 4     Atlantic    Boston Celtics
# ..         ...               ...
# 617  Southwest  Dallas Mavericks
# 618  Southwest  Dallas Mavericks
# 619  Southwest  Dallas Mavericks
# 620  Southwest  Dallas Mavericks
# 621  Southwest  Dallas Mavericks
#
# [622 rows x 2 columns]

# %%
# https://www.marsja.se/pandas-sample-randomly-select-rows/
# now let's get a sample
# w/o a parameter we'll just get 1 row
nbaStats.sample()
# but let's get a sample of 10
# nbaStats.sample(10)
# Out:
#     Conference   Division              Team           Player  Age  Games  \
# 605    Western  Southwest  Dallas Mavericks  Harrison Barnes   26     49
#
#      Games Started  Minutes Played  Field Goals  Field Goal Attempts  ...  \
# 605             49            1584          290                  717  ...
#
#      Free Throw Percentage  Offensive Rebounds  Defensive Rebounds  \
# 605                  0.833                  36                 171
#
#      Total Rebounds  Assists  Steals  Blocks  Turnovers  Personal Fouls  \
# 605             207       62      33      11         68              79
#
#      Points
# 605     866
#
# [1 rows x 30 columns]

# %%
# dataframes can be sliced, like numpy arrays or python lists
# use colons to specify the start, end and stride of a slice

#iloc is the position, loc is by label

# nbaStats.loc[:, ['Age']].max()
# nbaStats.loc[:, ['Games']].max()
# nbaStats.loc[:, ['Minutes Played']].max()
# nbaStats.loc[:, ['Field Goals']].max()
nbaStats.loc[:, ['Offensive Rebounds']].max()
# Out:
# Offensive Rebounds    423
# dtype: int64

# %%
#how to select an average from a column?
#here is the average age
nbaStats.loc[:, ['Age']].mean()
# Out:
# Age    26.048232
# dtype: float64

# %%
nbaStats.loc[:, ['Games']].median()
# nbaStats.loc[:, ['Games']].mean()
# Out:
# Games    43.0
# dtype: float64

# %%
# df.loc[:, ['col1', 'col2']]
# nbaStats.loc[:, ['Team', 'Player', 'Age', 'Games Played']]

# %%
# Now let's use IMDB ratings, from https://www.youtube.com/watch?v=hSrDViyKWVk
# https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/imdb_1000.csv
movieRatings = pd.read_csv("https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/imdb_1000.csv") 
movieRatings.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
# describe will just give you the numeric descriptive statistics of all number columns
movieRatings.describe()
# Out:
#        star_rating    duration
# count   979.000000  979.000000
# mean      7.889785  120.979571
# std       0.336069   26.218010
# min       7.400000   64.000000
# 25%       7.600000  102.000000
# 50%       7.800000  117.000000
# 75%       8.100000  134.000000
# max       9.300000  242.000000

# %%
# now let's try .describe on the NBA data
nbaStats.describe()
#NICE!
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5e576a211447> in <module>
#       1 # now let's try .describe on the NBA data
# ----> 2 nbaStats.describe()
#       3 #NICE!
#
# NameError: name 'nbaStats' is not defined

# %%
# shape just gives us a tuple
movieRatings.shape
# Out:
# (979, 6)

# %%
movieRatings.dtypes
# Out:
# star_rating       float64
# title              object
# content_rating     object
# genre              object
# duration            int64
# actors_list        object
# dtype: object

# %%
type(movieRatings)
# https://www.youtube.com/watch?v=hSrDViyKWVk

# so movieRatings is a dataframe, so has certain methods and attributes

# head, describe etc..

# attributes are those w/o parentheses, like shape and dtype

# methods are 'Actions'

# attributes are 'descriptions'

# attribute = NO parens

# more here on methods vs attributes:
# https://stackoverflow.com/questions/46312470/difference-between-methods-and-attributes-in-python
# Out:
# pandas.core.frame.DataFrame

# %%
# so if you want to see what you want to perform just type the . and tab
movieRatings.dtypes
# Out:
# star_rating       float64
# title              object
# content_rating     object
# genre              object
# duration            int64
# actors_list        object
# dtype: object

# %%
# so pd.read_csv is just a Pandas function, not a method on an object
# a dataframe method will sometimes require arguments 
# include = will describe columns with type of 'object'
movieRatings.describe(include=['object'])
# Out:
#             title content_rating  genre  \
# count         979            976    979
# unique        975             12     16
# top     True Grit              R  Drama
# freq            2            460    278
#
#                                               actors_list
# count                                                 979
# unique                                                969
# top     [u'Daniel Radcliffe', u'Emma Watson', u'Rupert...
# freq                                                    6

# %%
nbaStats.describe(include=['object'])
# Out:
#        Conference Division               Team           Player
# count         622      622                622              622
# unique          2        6                 30              530
# top       Eastern  Central  Memphis Grizzlies  Wesley Matthews
# freq          316      110                 28                3

# %%
#hit shift + tab inside the parentheses to see the arguments

# %%
#working from http://localhost:8888/notebooks/Desktop/PythonProjects/Udemy_Master%20Data%20Analysis%20with%20Python%20-%20Intro%20to%20Pandas/UdemyIntroToPandas.ipynb
# use group by, sex is a column and charges is a column in my 'college' dataset
# ins.groupby('sex').agg({'charges' : 'mean'}).round(-3)
# so just use a couple from the nba bit
nbaStats.groupby('Age').agg({'Games' : 'mean'})
# so this is showing mean age by games? not sure how useful that is
# Out:
#          Games
# Age
# 19   39.727273
# 20   55.000000
# 21   36.060000
# 22   38.280000
# 23   33.417910
# 24   45.226415
# 25   45.673077
# 26   41.909091
# 27   41.727273
# 28   41.020000
# 29   45.205882
# 30   47.805556
# 31   47.409091
# 32   39.884615
# 33   43.000000
# 34   42.454545
# 35   57.333333
# 36   38.250000
# 37   47.750000
# 38   26.000000
# 40   51.000000
# 42   76.000000

# %%
nbaStats.describe
# nbaStats.index.values
# Out:
# <bound method NDFrame.describe of     Conference   Division              Team                Player  Age  Games  \
# 0      Eastern   Atlantic    Boston Celtics          Jayson Tatum   20     79
# 1      Eastern   Atlantic    Boston Celtics          Kyrie Irving   26     67
# 2      Eastern   Atlantic    Boston Celtics          Marcus Smart   24     80
# 3      Eastern   Atlantic    Boston Celtics         Marcus Morris   29     75
# 4      Eastern   Atlantic    Boston Celtics            Al Horford   32     68
# ..         ...        ...               ...                   ...  ...    ...
# 617    Western  Southwest  Dallas Mavericks           Salah Mejri   32     36
# 618    Western  Southwest  Dallas Mavericks          Courtney Lee   33     22
# 619    Western  Southwest  Dallas Mavericks           Daryl Macon   23      8
# 620    Western  Southwest  Dallas Mavericks  Kostas Antetokounmpo   21      2
# 621    Western  Southwest  Dallas Mavericks          Ray Spalding   21      1
#
# ...

# %%
nbaStats.columns
# Out:
# Index(['Conference', 'Division', 'Team', 'Player', 'Age', 'Games',
#        'Games Started', 'Minutes Played', 'Field Goals', 'Field Goal Attempts',
#        'Field Goal Percentage', '3-Point Field Goals',
#        '3-Point Field Goal Attempts', '3-Point Field Goal Percentage',
#        '2-Point Field Goals', '2-Point Field Goal Attempts',
#        '2-Point Field Goal Percentage', 'Effective Field Goal Percentage',
#        'Free Throws', 'Free Throw Attempts', 'Free Throw Percentage',
#        'Offensive Rebounds', 'Defensive Rebounds', 'Total Rebounds', 'Assists',
#        'Steals', 'Blocks', 'Turnovers', 'Personal Fouls', 'Points'],
#       dtype='object')

# %%
 # More Drill sfrom here: https://towardsdatascience.com/pandas-cheat-sheet-4c4eb6802a4b
import pandas as pd
# creating a dataframe with all the grades and subjects
grades = pd.DataFrame(
                 {'Math'     : [80, 89, 93,66, 84, 85,74,64],
                  'Science'  : [94, 76, 88, 78, 88, 92, 60, 85],
                  'English'  : [83, 76, 93, 96, 77, 85, 92, 60],
                  'History'  : [96, 66, 76, 85, 78, 88, 69, 99]})

# %%
grades
# Out:
#    Math  Science  English  History
# 0    80       94       83       96
# 1    89       76       76       66
# 2    93       88       93       76
# 3    66       78       96       85
# 4    84       88       77       78
# 5    85       92       85       88
# 6    74       60       92       69
# 7    64       85       60       99

# %%
# just get the colmnns:
grades.columns
# Out:
# Index(['Math', 'Science', 'English', 'History'], dtype='object')

# %%
grades.describe()
grades.style.highlight_max(color='purple')
grades.style.highlight_min(color='red')
# Out:
# <style  type="text/css" >
#     #T_5e43f99e_7c2c_11ea_b8e1_7cb27dedc1c7row1_col3 {
#             background-color:  red;
#         }    #T_5e43f99e_7c2c_11ea_b8e1_7cb27dedc1c7row6_col1 {
#             background-color:  red;
#         }    #T_5e43f99e_7c2c_11ea_b8e1_7cb27dedc1c7row7_col0 {
#             background-color:  red;
#         }    #T_5e43f99e_7c2c_11ea_b8e1_7cb27dedc1c7row7_col2 {
#             background-color:  red;
#         }</style><table id="T_5e43f99e_7c2c_11ea_b8e1_7cb27dedc1c7" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Math</th>        <th class="col_heading level0 col1" >Science</th>        <th class="col_heading level0 col2" >English</th>        <th class="col_heading level0 col3" >History</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5e43f99e_7c2c_11ea_b8e1_7cb27dedc1c7level0_row0" class="row_heading level0 row0" >0</th>
# ...

# %%
# Using the .describe() function we automatically get quantiles for 25, 50, and 75. 
# Create your own quantiles like this:
grades.describe([0.1, 0.4, 0.5, 0.6, 0.7, 0.8, 0.9])
# grades.describe([0.1, 0.9])
# Out:
#             Math    Science    English    History
# count   8.000000   8.000000   8.000000   8.000000
# mean   79.375000  82.625000  82.750000  82.125000
# std    10.528024  11.070392  11.756457  11.993302
# min    64.000000  60.000000  60.000000  66.000000
# 10%    65.400000  71.200000  71.200000  68.100000
# 40%    78.800000  83.600000  81.800000  77.600000
# 50%    82.000000  86.500000  84.000000  81.500000
# 60%    84.200000  88.000000  86.400000  85.600000
# 70%    84.900000  88.000000  91.300000  87.700000
# 80%    87.400000  90.400000  92.600000  92.800000
# 90%    90.200000  92.600000  93.900000  96.900000
# max    93.000000  94.000000  96.000000  99.000000

# %%
# More on quantiles: 
    # https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.quantile.html
# Basically, quantiles are just lines that divide data into equally-sized groups
