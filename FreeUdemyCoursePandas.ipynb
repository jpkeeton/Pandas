# %%
# working from file:///C:/Users/jpkee/AppData/Local/Temp/Temp1_original.zip/Master%20Data%20Analysis%20with%20Python%20-%20Intro%20to%20pandas/Book/Master%20Data%20Analysis%20with%20Python%20-%20Intro%20to%20Pandas.pdf
# https://www.udemy.com/course/master-data-analysis-with-python-intro-to-pandas/learn/lecture/13934504#overview

# %% [markdown]
# **With Pandas you can:**
# * filter
# * aggregate
# * tidy
# * group
# * join
# * perform time series
# * more!

# %% [markdown]
# **Why Pandas?**
# * Python library that integrates well w other data science libraries
#     * numpy sckikit-learn, statsmodels, matplotlib, seaborn
# * Self-contained, lots of functionality in one package
# * excellent community
#
# **Fun facts:**
# * name comes from *pan*el *da*ta
#     * pan da, get it?
# * Pandas is built directly on NumPy
# * a lot of data is stored in numpy arrays and relys on NumPy for calcs
# * relies on tabular data, (aka rows & columns)
# * Pandas does not do 3 or more dimensions or machine learning, just data analysis on 2 dimensional tabular data

# %% [markdown]
# **Pandas Examples**
# * just to see what's possible

# %%
# import Pandas library
import pandas as pd
# create a variable and read in data
# also there's a ton you can do with the read_csv function
    # https://www.geeksforgeeks.org/python-read-csv-using-pandas-read_csv/ 
bikes = pd.read_csv('C:/Users/jpkee/Desktop/PythonProjects/Master Data Analysis with Python - Intro to pandas/data/bikes.csv')
# apply the head function and get the first 2 rows
bikes.head(2)
# Out:
#    trip_id    usertype gender            starttime             stoptime  \
# 0     7147  Subscriber   Male  2013-06-28 19:01:00  2013-06-28 19:17:00
# 1     7524  Subscriber   Male  2013-06-28 22:53:00  2013-06-28 23:03:00
#
#    tripduration             from_station_name  latitude_start  \
# 0           993     Lake Shore Dr & Monroe St        41.88105
# 1           623  Clinton St & Washington Blvd        41.88338
#
#    longitude_start  dpcapacity_start        to_station_name  latitude_end  \
# 0        -87.61697              11.0  Michigan Ave & Oak St      41.90096
# 1        -87.64117              31.0   Wells St & Walton St      41.89993
#
#    longitude_end  dpcapacity_end  temperature  visibility  wind_speed  \
# 0     -87.623777            15.0         73.9        10.0        12.7
# 1     -87.634430            19.0         69.1        10.0         6.9
#
#    precipitation        events
# 0        -9999.0  mostlycloudy
# 1        -9999.0  partlycloudy

# %%
# shape returns a tuple representing the dimensionality of the datafram
bikes.shape
# Out:
# (50089, 19)

# %% [markdown]
# **Filtering on conditions**

# %%
# now let's filter on trip duration
tripD = bikes["tripduration"]> 4000
# print[tripD].head() - WRONG!
# grab the dataframe of 'bikes' and the new variable of 'tripD' and pull just the top x
bikes[tripD].head(2)
# Out:
#     trip_id    usertype  gender            starttime             stoptime  \
# 18    40924  Subscriber    Male  2013-07-09 13:12:00  2013-07-09 14:42:00
# 40    61401  Subscriber  Female  2013-07-14 14:08:00  2013-07-14 15:53:00
#
#     tripduration          from_station_name  latitude_start  longitude_start  \
# 18          5396    Canal St & Jackson Blvd       41.878114       -87.639971
# 40          6274  Wabash Ave & Roosevelt Rd       41.867173       -87.625955
#
#     dpcapacity_start            to_station_name  latitude_end  longitude_end  \
# 18              35.0            Millennium Park     41.881032     -87.624084
# 40              19.0  Lake Shore Dr & Monroe St     41.881050     -87.616970
#
#     dpcapacity_end  temperature  visibility  wind_speed  precipitation  \
# 18            35.0         79.0        10.0        13.8            0.0
# 40            11.0         87.1        10.0         8.1        -9999.0
#
#           events
# 18        cloudy
# 40  partlycloudy

# %% [markdown]
# **Filter on multiple conditions**

# %%
# now filter on multiple conditions
# using a greater than
filter1 = bikes["tripduration"]> 4000
# and a not equal to here
filter2 = bikes["gender"]!='Male'
combo = filter1 & filter2
# get all the results
# bikes[combo]
# get just the head
bikes[combo].head(3)
# you can get the shape here
# bikes[combo].shape
# Out:
#       trip_id    usertype  gender            starttime             stoptime  \
# 40      61401  Subscriber  Female  2013-07-14 14:08:00  2013-07-14 15:53:00
# 77      87005  Subscriber  Female  2013-07-21 11:35:00  2013-07-21 13:54:00
# 1954  1103416  Subscriber  Female  2013-12-28 11:37:00  2013-12-28 13:34:00
#
#       tripduration           from_station_name  latitude_start  \
# 40            6274   Wabash Ave & Roosevelt Rd       41.867173
# 77            8299          State St & 19th St       41.856594
# 1954          7050  LaSalle St & Washington St       41.882664
#
#       longitude_start  dpcapacity_start               to_station_name  \
# 40         -87.625955              19.0     Lake Shore Dr & Monroe St
# 77         -87.627542              15.0  Sheffield Ave & Kingsbury St
# 1954       -87.632530              15.0           Theater on the Lake
#
#       latitude_end  longitude_end  dpcapacity_end  temperature  visibility  \
# ...

# %%
bikes[tripD].head(2)
# Out:
#     trip_id    usertype  gender            starttime             stoptime  \
# 18    40924  Subscriber    Male  2013-07-09 13:12:00  2013-07-09 14:42:00
# 40    61401  Subscriber  Female  2013-07-14 14:08:00  2013-07-14 15:53:00
#
#     tripduration          from_station_name  latitude_start  longitude_start  \
# 18          5396    Canal St & Jackson Blvd       41.878114       -87.639971
# 40          6274  Wabash Ave & Roosevelt Rd       41.867173       -87.625955
#
#     dpcapacity_start            to_station_name  latitude_end  longitude_end  \
# 18              35.0            Millennium Park     41.881032     -87.624084
# 40              19.0  Lake Shore Dr & Monroe St     41.881050     -87.616970
#
#     dpcapacity_end  temperature  visibility  wind_speed  precipitation  \
# 18            35.0         79.0        10.0        13.8            0.0
# 40            11.0         87.1        10.0         8.1        -9999.0
#
#           events
# 18        cloudy
# 40  partlycloudy

# %%
gender = bikes["gender"] == "male"
bikes["gender"].head()
# Out:
# 0    Male
# 1    Male
# 2    Male
# 3    Male
# 4    Male
# Name: gender, dtype: object

# %%
tripAndGender = tripD & gender

# %%
bikes[tripAndGender].head(5)
# Out:
# Empty DataFrame
# Columns: [trip_id, usertype, gender, starttime, stoptime, tripduration, from_station_name, latitude_start, longitude_start, dpcapacity_start, to_station_name, latitude_end, longitude_end, dpcapacity_end, temperature, visibility, wind_speed, precipitation, events]
# Index: []

# %%
# hrrm, not quite working, let's try gender again, building off of the first trip duration example
gender = bikes["gender"] == "Female"
# grab the dataframe of 'bikes' and the new variable of 'gender' and pull just the top x 
bikes[gender].head(2)
# Out:
#     trip_id    usertype  gender            starttime             stoptime  \
# 9     23558  Subscriber  Female  2013-07-04 15:00:00  2013-07-04 15:16:00
# 14    31121  Subscriber  Female  2013-07-06 12:39:00  2013-07-06 12:49:00
#
#     tripduration              from_station_name  latitude_start  \
# 9            922  Lakeview Ave & Fullerton Pkwy       41.925858
# 14           610            Morgan St & Lake St       41.885483
#
#     longitude_start  dpcapacity_start             to_station_name  \
# 9        -87.638973              19.0  Racine Ave & Congress Pkwy
# 14       -87.652305              15.0  Aberdeen St & Jackson Blvd
#
#     latitude_end  longitude_end  dpcapacity_end  temperature  visibility  \
# 9      41.874640     -87.657030            19.0         81.0        10.0
# 14     41.877726     -87.654787            15.0         82.0        10.0
#
#     wind_speed  precipitation        events
# 9         12.7        -9999.0  mostlycloudy
# ...

# %%
# now let's try again to filter on multiple conditions
# create a new variable 
combined = tripD & gender
# now output the result
bikes[combined].head()
# Out:
#       trip_id    usertype  gender            starttime             stoptime  \
# 40      61401  Subscriber  Female  2013-07-14 14:08:00  2013-07-14 15:53:00
# 77      87005  Subscriber  Female  2013-07-21 11:35:00  2013-07-21 13:54:00
# 1954  1103416  Subscriber  Female  2013-12-28 11:37:00  2013-12-28 13:34:00
# 2712  1416670  Subscriber  Female  2014-04-15 15:56:00  2014-04-16 14:09:00
# 2915  1499497  Subscriber  Female  2014-04-25 13:01:00  2014-04-25 16:27:00
#
#       tripduration             from_station_name  latitude_start  \
# 40            6274     Wabash Ave & Roosevelt Rd       41.867173
# 77            8299            State St & 19th St       41.856594
# 1954          7050    LaSalle St & Washington St       41.882664
# 2712         79988  Clinton St & Washington Blvd       41.883380
# 2915         12351            May St & Taylor St       41.869482
#
#       longitude_start  dpcapacity_start               to_station_name  \
# ...

# %% [markdown]
# Filtering on **OR** condition

# %%
# to OR, just use the pipe separator instead of &
combinedOR = tripD | gender
# now output the result
bikes[combinedOR].head()
# Out:
#     trip_id    usertype  gender            starttime             stoptime  \
# 9     23558  Subscriber  Female  2013-07-04 15:00:00  2013-07-04 15:16:00
# 14    31121  Subscriber  Female  2013-07-06 12:39:00  2013-07-06 12:49:00
# 18    40924  Subscriber    Male  2013-07-09 13:12:00  2013-07-09 14:42:00
# 20    42488  Subscriber  Female  2013-07-09 17:39:00  2013-07-09 17:55:00
# 21    42818  Subscriber  Female  2013-07-09 19:26:00  2013-07-09 19:38:00
#
#     tripduration              from_station_name  latitude_start  \
# 9            922  Lakeview Ave & Fullerton Pkwy       41.925858
# 14           610            Morgan St & Lake St       41.885483
# 18          5396        Canal St & Jackson Blvd       41.878114
# 20           943        State St & Van Buren St       41.877181
# 21           726         Clark St & Randolph St       41.884576
#
#     longitude_start  dpcapacity_start             to_station_name  \
# ...

# %% [markdown]
# **Aggregating Methods**
# * aggregation -> a function that returns a single value

# %%
# using the 'college' data set
## don't forget the index_col at the end 'index_col='instnm'
college = pd.read_csv('C:/Users/jpkee/Desktop/PythonProjects/Udemy_Master Data Analysis with Python - Intro to Pandas/Master Data Analysis with Python - Intro to pandas/data/college.csv', index_col='instnm')
# college.shape
# college.describe
# college.sample()
# so here we're defining the range with the 'white' and 'unkn' elements
cr = college.loc[:, 'ugds_white' : 'ugds_unkn']
cr.head()
# Out:
#                                      ugds_white  ugds_black  ugds_hisp  \
# instnm
# Alabama A & M University                 0.0333      0.9353     0.0055
# University of Alabama at Birmingham      0.5922      0.2600     0.0283
# Amridge University                       0.2990      0.4192     0.0069
# University of Alabama in Huntsville      0.6988      0.1255     0.0382
# Alabama State University                 0.0158      0.9208     0.0121
#
#                                      ugds_asian  ugds_aian  ugds_nhpi  \
# instnm
# Alabama A & M University                 0.0019     0.0024     0.0019
# University of Alabama at Birmingham      0.0518     0.0022     0.0007
# Amridge University                       0.0034     0.0000     0.0000
# University of Alabama in Huntsville      0.0376     0.0143     0.0002
# Alabama State University                 0.0019     0.0010     0.0006
#
#                                      ugds_2mor  ugds_nra  ugds_unkn
# instnm
# ...

# %%
# More on mean here: https://www.geeksforgeeks.org/python-pandas-dataframe-mean
# default is to go vertically
cr.mean()
# Out:
# ugds_white    0.510207
# ugds_black    0.189997
# ugds_hisp     0.161635
# ugds_asian    0.033544
# ugds_aian     0.013813
# ugds_nhpi     0.004569
# ugds_2mor     0.023950
# ugds_nra      0.016086
# ugds_unkn     0.045181
# dtype: float64

# %%
# you can also run the mean horizontally, with the axis parameter, every row will counted
cr.sum(axis=1).head()
# Out:
# instnm
# Alabama A & M University               1.0000
# University of Alabama at Birmingham    0.9999
# Amridge University                     1.0000
# University of Alabama in Huntsville    1.0000
# Alabama State University               1.0000
# dtype: float64

# %% [markdown]
# **Non-aggregating Methods**

# %%
# methods that do not return a single value, take in values and output the same number of values
# the 2 below rounds the decimal
cr.round(2).head()
# Out:
#                                      ugds_white  ugds_black  ugds_hisp  \
# instnm
# Alabama A & M University                   0.03        0.94       0.01
# University of Alabama at Birmingham        0.59        0.26       0.03
# Amridge University                         0.30        0.42       0.01
# University of Alabama in Huntsville        0.70        0.13       0.04
# Alabama State University                   0.02        0.92       0.01
#
#                                      ugds_asian  ugds_aian  ugds_nhpi  \
# instnm
# Alabama A & M University                   0.00       0.00        0.0
# University of Alabama at Birmingham        0.05       0.00        0.0
# Amridge University                         0.00       0.00        0.0
# University of Alabama in Huntsville        0.04       0.01        0.0
# Alabama State University                   0.00       0.00        0.0
#
#                                      ugds_2mor  ugds_nra  ugds_unkn
# instnm
# ...

# %% [markdown]
# **Aggregating w/in Groups**

# %%
# using the insurance data set
ins = pd.read_csv('C:/Users/jpkee/Desktop/PythonProjects/Udemy_Master Data Analysis with Python - Intro to Pandas/Master Data Analysis with Python - Intro to pandas/data/insurance.csv')
ins.head()
# each row represents a person and the last column shows total charges
# value counts - counts unique values in one particulart column
# more here on this: https://www.geeksforgeeks.org/python-pandas-index-value_counts
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# **Count Frequency of one column**

# %%
ins['region'].value_counts()
# Out:
# southeast    364
# northwest    325
# southwest    325
# northeast    324
# Name: region, dtype: int64

# %%
# use group by
# group by one particular column and aggregate on a different column
# here we'll group by sex and aggregate on the mean of the charges
ins.groupby('sex').agg({'charges' : 'mean'}).round(-3)
# so we'll get the mean charges per sex
# Out:
#         charges
# sex
# female  13000.0
# male    14000.0

# %%
ins.index
# Out:
# RangeIndex(start=0, stop=1338, step=1)

# %% [markdown]
# **4/8/20, back in!**
# * https://www.udemy.com/course/master-data-analysis-with-python-intro-to-pandas/learn/lecture/13934766?start=555#content

# %% [markdown]
# Aggregating w/in groups

# %%
# creating a new variable here just to reboot my efforts:
ins2 = pd.read_csv('C:/Users/jpkee/Desktop/PythonProjects/Udemy_Master Data Analysis with Python - Intro to Pandas/Master Data Analysis with Python - Intro to pandas/data/insurance.csv')
#checking that it's working
# print(ins2)
# ins2.head
# it is, now get the shape
ins2.shape
# Out:
# (1338, 7)

# %%
#now let's count the frequency of one column
# Pandas Index.value_counts() function returns object containing counts of unique values. 

# value_counts is a major method, to get a count of unique values in one particular column
# So if we wanted to get a count of unique values with a column like region we can do that
ins2['region'].value_counts()
# Out:
# southeast    364
# northwest    325
# southwest    325
# northeast    324
# Name: region, dtype: int64

# %% [markdown]
# so we'll get a count eah instance of region
#
# southeast    364
#
# northwest    325
#
# southwest    325
#
# northeast    324
#
# Name: region, dtype: int64

# %%
# so again, group by sex and aggregated on mean pf charges
# multiple aggregations
ins2.groupby('sex').agg({'charges' : 'mean'}).round(-3)
# Out:
#         charges
# sex
# female  13000.0
# male    14000.0

# %%
# but what if we want aggregate on multiple conditions?
# group by sex, and aggregate on mean, count and max for the charges column
ins2.groupby('sex').agg({'charges' : ['mean', 'count', 'max']}).round()
# Out:
#         charges
#            mean count      max
# sex
# female  12570.0   662  63770.0
# male    13957.0   676  62593.0

# %%
#now let's try that for the NBA data set
nbaStats = pd.read_csv("C:/Users/jpkee/Desktop/PythonProjects/NBA 2018-19 Season.csv") 
# Groupby Games and aggregate on the various field goal measures
nbaStats.groupby('Games').agg({'Field Goals' :['count', 'mean', 'max', 'median']}).round(1)
# Out:
#       Field Goals
#             count   mean  max median
# Games
# 1              20    0.8    6    0.0
# 2              14    2.1    4    2.5
# 3              14    3.4   15    2.0
# 4              15    6.2   29    4.0
# 5               3    6.0    8    6.0
# ...           ...    ...  ...    ...
# 78              6  558.8  843  562.5
# 79              9  400.7  561  431.0
# 80             14  395.1  701  326.5
# 81             18  419.1  684  441.5
# 82             19  383.8  764  341.0
#
# [82 rows x 4 columns]

# %% [markdown]
# Grouping on Mutiple Columns

# %%
#now let's group on multiple columns
#group by games AND age
nbaStats.groupby(['Games', 'Age']).agg({'Field Goals' : ['count', 'mean', 'max']}).round(1)
# Out:
#           Field Goals
#                 count   mean  max
# Games Age
# 1     21            3    0.0    0
#       22            2    0.0    0
#       23            4    0.8    1
#       24            2    1.5    2
#       25            2    3.0    6
# ...               ...    ...  ...
# 82    27            1  226.0  226
#       28            3  478.0  731
#       30            1  282.0  282
#       31            1  359.0  359
#       33            1  207.0  207
#
# [479 rows x 3 columns]

# %% [markdown]
# Multiple Grouping Columns, again, with the insurance data

# %%
ins2.groupby(['sex', 'region']).agg({'charges': ['mean', 'count', 'max']}).round(0)
# Out:
#                   charges
#                      mean count      max
# sex    region
# female northeast  12953.0   161  58571.0
#        northwest  12480.0   164  55135.0
#        southeast  13500.0   175  63770.0
#        southwest  11274.0   162  48824.0
# male   northeast  13854.0   163  48549.0
#        northwest  12354.0   161  60021.0
#        southeast  15880.0   189  62593.0
#        southwest  13413.0   163  52591.0

# %%
#here with a different rounding option
ins2.groupby(['sex', 'region']).agg({'charges': ['mean', 'count', 'max']}).round(2)
# Out:
#                    charges
#                       mean count       max
# sex    region
# female northeast  12953.20   161  58571.07
#        northwest  12479.87   164  55135.40
#        southeast  13499.67   175  63770.43
#        southwest  11274.41   162  48824.45
# male   northeast  13854.01   163  48549.18
#        northwest  12354.12   161  60021.40
#        southeast  15879.62   189  62592.87
#        southwest  13412.88   163  52590.83

# %% [markdown]
# But, what if you don't want this layout?
#
# Try the Pivot Table:
# * https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.pivot_table.html
# * https://pbpython.com/pandas-pivot-table-explained.html

# %%
# Pivot Tables are here in the Udemy course: https://www.udemy.com/course/master-data-analysis-with-python-intro-to-pandas/learn/lecture/13934766?start=555#content
#here we go w a pivot table

pt = ins2.pivot_table(index='sex', columns='region', values='charges', aggfunc='mean').round(0)

# %%
pt
# Out:
# region  northeast  northwest  southeast  southwest
# sex
# female    12953.0    12480.0    13500.0    11274.0
# male      13854.0    12354.0    15880.0    13413.0

# %%
#now let's STYLE a pivot table
# https://pandas.pydata.org/pandas-docs/stable/user_guide/style.html
# highlighting the min
pt.style.highlight_min(color='red')
#this only works with https://towardsdatascience.com/style-pandas-dataframe-like-a-master-6b02bf6468b0
# pt.style.background_gradient(cmap='Blues')
# Out:
# <style  type="text/css" >
#     #T_847b91ec_7c2b_11ea_88cb_7cb27dedc1c7row0_col0 {
#             background-color:  red;
#         }    #T_847b91ec_7c2b_11ea_88cb_7cb27dedc1c7row0_col2 {
#             background-color:  red;
#         }    #T_847b91ec_7c2b_11ea_88cb_7cb27dedc1c7row0_col3 {
#             background-color:  red;
#         }    #T_847b91ec_7c2b_11ea_88cb_7cb27dedc1c7row1_col1 {
#             background-color:  red;
# ...

# %%
# highlighting the max
pt.style.highlight_max(color='#b1eb34')
# Out:
# <style  type="text/css" >
#     #T_847d8c62_7c2b_11ea_a023_7cb27dedc1c7row0_col1 {
#             background-color:  #b1eb34;
#         }    #T_847d8c62_7c2b_11ea_a023_7cb27dedc1c7row1_col0 {
#             background-color:  #b1eb34;
#         }    #T_847d8c62_7c2b_11ea_a023_7cb27dedc1c7row1_col2 {
#             background-color:  #b1eb34;
#         }    #T_847d8c62_7c2b_11ea_a023_7cb27dedc1c7row1_col3 {
#             background-color:  #b1eb34;
# ...

# %% [markdown]
# **Tidying**

# %%
planeCrash= pd.read_csv('C:/Users/jpkee/Desktop/PythonProjects/Udemy_Master Data Analysis with Python - Intro to Pandas/Master Data Analysis with Python - Intro to pandas/data/planecrashinfo.csv')
planeCrash.head(2)
#now, see the questions marks? those are missing values
# Out:
#                  date   time                 location              operator  \
# 0  September 17, 1908  17:18      Fort Myer, Virginia  Military - U.S. Army
# 1  September 07, 1909      ?  Juvisy-sur-Orge, France                     ?
#
#   flight_no          route           ac_type registration cn_ln  \
# 0         ?  Demonstration  Wright Flyer III            ?     1
# 1         ?       Air show    Wright Byplane          SC1     ?
#
#                        aboard                  fatalities ground  \
# 0  2   (passengers:1  crew:1)  1   (passengers:1  crew:0)      0
# 1  1   (passengers:0  crew:1)  1   (passengers:0  crew:0)      0
#
#                                              summary
# 0  During a demonstration flight, a U.S. Army fly...
# 1  Eugene Lefebvre was the first pilot to ever be...

# %%
# so let's get ride of the missing values
# set the 'na_values' parameter w/in the read_csv function with '?' 
# to change to 'NaN', aka not a number
planeCrash= pd.read_csv('C:/Users/jpkee/Desktop/PythonProjects/Udemy_Master Data Analysis with Python - Intro to Pandas/Master Data Analysis with Python - Intro to pandas/data/planecrashinfo.csv', na_values="?")
planeCrash.head(3)
# Out:
#                  date   time                   location              operator  \
# 0  September 17, 1908  17:18        Fort Myer, Virginia  Military - U.S. Army
# 1  September 07, 1909    NaN    Juvisy-sur-Orge, France                   NaN
# 2       July 12, 1912  06:30  Atlantic City, New Jersey  Military - U.S. Navy
#
#   flight_no          route           ac_type registration cn_ln  \
# 0       NaN  Demonstration  Wright Flyer III          NaN     1
# 1       NaN       Air show    Wright Byplane          SC1   NaN
# 2       NaN    Test flight         Dirigible          NaN   NaN
#
#                        aboard                  fatalities  ground  \
# 0  2   (passengers:1  crew:1)  1   (passengers:1  crew:0)     0.0
# 1  1   (passengers:0  crew:1)  1   (passengers:0  crew:0)     0.0
# 2  5   (passengers:0  crew:5)  5   (passengers:0  crew:5)     0.0
#
#                                              summary
# 0  During a demonstration flight, a U.S. Army fly...
# ...

# %%
#now notice the 'aboard' column has a buncha text, let's just look at that one.
# how do you get just one column back?
acType = planeCrash['ac_type']
aboardDetails = planeCrash['aboard']

aboardDetails.head(5)
# acType.head(5)

#there are 3 pieces of data
# Out:
# 0     2   (passengers:1  crew:1)
# 1     1   (passengers:0  crew:1)
# 2     5   (passengers:0  crew:5)
# 3     1   (passengers:0  crew:1)
# 4    20   (passengers:?  crew:?)
# Name: aboard, dtype: object

# %%
#now let's use some regex to extract stuff here:
# didn't quite get the regext so will cirle back
# aboardDetails.str.extract(r'(\d+)?\D*(\d+)?\D*(\d+?').head(4)

# %% [markdown]
# **Melt example**
# * From: https://www.journaldev.com/33398/pandas-melt-unmelt-pivot-function
#     * Pandas melt() function is used to *change the DataFrame format from wide to long*.
#     * It's used to create a specific format of the DataFrame object where one or more columns work as identifiers.
#
#     * All the remaining columns are treated as values and unpivoted to the row axis and only two columns – variable and value.

# %% [markdown]
# **Joining** - NOT WORKING, think the DB path is just bad
#
# 'merge' is used to make SQL-style joins in Pandas

# %%
# from sqlalchemy import create_engine
# # engine = create_engine('sqlite:///../data/neuralips2015.sqlite')
# engine = create_engine('sqlite:/C:/Users/jpkee/Desktop/PythonProjects/Master Data Analysis with Python - Intro to pandas/data/neurIPS.sqlite')
# engine.table_names()
# # C:/Users/jpkee/Desktop/PythonProjects/Master Data Analysis with Python - Intro to pandas/data/neurIPS.db'

# %% [markdown]
# **Time Series**
# * We'll use and API call - also not working

# %%
# #not working yet
# aapl = pd.read_json('https://api.iextrading.com/1.0/stock/aapl/chart/5y')
# aapl = pd.read_json('https://api.iextrading.com/1.0/stock/aapl/chart/5y')

# # https://api.iexapis.com/v1/stock/aapl/chart/5y

# %% [markdown]
# **Setting a meaningful Index**
#
# Objectives:
# * Extract the components of a DataFrame
# * Understand what makes a meaningful index
# * https://www.udemy.com/course/master-data-analysis-with-python-intro-to-pandas/learn/lecture/13947512#overview

# %%
import pandas as pd

# %%
# this will give you a numbered index, the default
# sampleData = pd.read_csv('C:/Users/jpkee/Desktop/PythonProjects/Master Data Analysis with Python - Intro to pandas/data/sample_data.csv')

# this will give you an index with the name, using the 'index_col=0' bit, forces the first column in the .csv to be the index
sampleData = pd.read_csv('C:/Users/jpkee/Desktop/PythonProjects/Master Data Analysis with Python - Intro to pandas/data/sample_data.csv', index_col=0)

# %%
sampleData.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-fead1abda02d> in <module>
# ----> 1 sampleData.head()
#
# NameError: name 'sampleData' is not defined

# %%
# get the index
sampleData.index
# again, NO PARENS = an attribute
# Out:
# Index(['Jane', 'Niko', 'Aaron', 'Penelope', 'Dean', 'Christina', 'Cornelia'], dtype='object')

# %%
# get the columns
sampleData.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ca3c46adf46e> in <module>
#       1 # get the columns
# ----> 2 sampleData.columns
#
# NameError: name 'sampleData' is not defined

# %%
# How to get multiple columns from a df
coupleColumns = ['state', 'color']
sampleData[coupleColumns]
# Out:
#           state  color
# Jane         NY   blue
# Niko         TX  green
# Aaron        FL    red
# Penelope     AL  white
# Dean         AK   gray
# Christina    TX  black
# Cornelia     TX    red

# %%
sampleData.values
# Out:
# array([['NY', 'blue', 'Steak', 30, 165, 4.6],
#        ['TX', 'green', 'Lamb', 2, 70, 8.3],
#        ['FL', 'red', 'Mango', 12, 120, 9.0],
#        ['AL', 'white', 'Apple', 4, 80, 3.3],
#        ['AK', 'gray', 'Cheese', 32, 180, 1.8],
#        ['TX', 'black', 'Melon', 33, 172, 9.5],
#        ['TX', 'red', 'Beans', 69, 150, 2.2]], dtype=object)

# %%
# now create variables with those bits
cols = sampleData.columns
vals = sampleData.values
indy = sampleData.index

# %%
cols
# Out:
# Index(['state', 'color', 'food', 'age', 'height', 'score'], dtype='object')

# %%
vals
# Out:
# array([['NY', 'blue', 'Steak', 30, 165, 4.6],
#        ['TX', 'green', 'Lamb', 2, 70, 8.3],
#        ['FL', 'red', 'Mango', 12, 120, 9.0],
#        ['AL', 'white', 'Apple', 4, 80, 3.3],
#        ['AK', 'gray', 'Cheese', 32, 180, 1.8],
#        ['TX', 'black', 'Melon', 33, 172, 9.5],
#        ['TX', 'red', 'Beans', 69, 150, 2.2]], dtype=object)

# %%
indy
# Out:
# Index(['Jane', 'Niko', 'Aaron', 'Penelope', 'Dean', 'Christina', 'Cornelia'], dtype='object')

# %% [markdown]
# # What ARE these?

# %%
type(vals)
# Out:
# numpy.ndarray

# %%
type(cols)
# Out:
# pandas.core.indexes.base.Index

# %%
type(indy)
# Out:
# pandas.core.indexes.base.Index

# %% [markdown]
# # Extract components of a series

# %%
color = sampleData['color']
color
# and the index comes along w it
# Out:
# Jane          blue
# Niko         green
# Aaron          red
# Penelope     white
# Dean          gray
# Christina    black
# Cornelia       red
# Name: color, dtype: object

# %%
color.index
# Out:
# Index(['Jane', 'Niko', 'Aaron', 'Penelope', 'Dean', 'Christina', 'Cornelia'], dtype='object')

# %%
color.values
# Out:
# array(['blue', 'green', 'red', 'white', 'gray', 'black', 'red'],
#       dtype=object)

# %%
# so, just set your index by integer or string
# let's grab the movie data set and set the index to 'title'
movieData = pd.read_csv('C:/Users/jpkee/Desktop/PythonProjects/Master Data Analysis with Python - Intro to pandas/data/movie.csv', index_col='title')
movieData
# Out:
#                                               year  color content_rating  \
# title
# Avatar                                      2009.0  Color          PG-13
# Pirates of the Caribbean: At World's End    2007.0  Color          PG-13
# Spectre                                     2015.0  Color          PG-13
# The Dark Knight Rises                       2012.0  Color          PG-13
# Star Wars: Episode VII - The Force Awakens     NaN    NaN            NaN
# ...                                            ...    ...            ...
# Signed Sealed Delivered                     2013.0  Color            NaN
# The Following                                  NaN  Color          TV-14
# A Plague So Pleasant                        2013.0  Color            NaN
# Shanghai Calling                            2012.0  Color          PG-13
# My Date with Drew                           2004.0  Color             PG
#
#                                             duration      director_name  \
# title
# ...

# %%
type(movieData)
# Out:
# pandas.core.frame.DataFrame

# %%
# you can also use the set_index method, which creates a NEW object
# https://pandas.pydata.org/pandas-docs/version/0.21.1/generated/pandas.DataFrame.set_index.html

# Pandas set_index() is a method to set a List, Series or Data frame as index of a Data Frame. 
# Index column can be set while making a data frame too. 
# But sometimes a data frame is made out of two or more data frames and hence later index can be changed using this method.

# %%
# Pandas onnly shows 20 columsn by default
# How do I see more?
# change the display options!

movieData.shape
# Out:
# (4916, 21)

# %%
pd.get_option('display.max_columns')
# Out:
# 20

# %%
#so here I'm just saying, 'hey pands, when i call my dataframe, just give me back 5 columns, or whatever number I have in there'
pd.set_option('display.max_columns', 50)
pd.get_option
#use shift + tab + tab to get to the documentation

# %%
movieData
# Out:
#                                               year  color content_rating  \
# title
# Avatar                                      2009.0  Color          PG-13
# Pirates of the Caribbean: At World's End    2007.0  Color          PG-13
# Spectre                                     2015.0  Color          PG-13
# The Dark Knight Rises                       2012.0  Color          PG-13
# Star Wars: Episode VII - The Force Awakens     NaN    NaN            NaN
# ...                                            ...    ...            ...
# Signed Sealed Delivered                     2013.0  Color            NaN
# The Following                                  NaN  Color          TV-14
# A Plague So Pleasant                        2013.0  Color            NaN
# Shanghai Calling                            2012.0  Color          PG-13
# My Date with Drew                           2004.0  Color             PG
#
#                                             duration      director_name  \
# title
# ...

# %% [markdown]
# **Exercises!**

# %%
# Read in the movie dataset, set the index to something other than movie title

movieDrills = pd.read_csv('C:/Users/jpkee/Desktop/PythonProjects/Master Data Analysis with Python - Intro to pandas/data/movie.csv', index_col='director_name')
movieDrills.head(2)
# Out:
#                                                    title    year  color  \
# director_name
# James Cameron                                     Avatar  2009.0  Color
# Gore Verbinski  Pirates of the Caribbean: At World's End  2007.0  Color
#
#                content_rating  duration  director_fb       actor1  actor1_fb  \
# director_name
# James Cameron           PG-13     178.0          0.0  CCH Pounder     1000.0
# Gore Verbinski          PG-13     169.0        563.0  Johnny Depp    40000.0
#
#                           actor2  actor2_fb          actor3  actor3_fb  \
# director_name
# James Cameron   Joel David Moore      936.0       Wes Studi      855.0
# Gore Verbinski     Orlando Bloom     5000.0  Jack Davenport     1000.0
#
#                       gross                           genres  num_reviews  \
# director_name
# James Cameron   760505847.0  Action|Adventure|Fantasy|Sci-Fi        723.0
# Gore Verbinski  309404152.0         Action|Adventure|Fantasy        302.0
#
# ...

# %%
# now set_index practice
# point here is to be able to read the documentation

# again, just think of an index as a list that can be sliced on etc...
movieDrills.set_index('title', drop=False)
movieDrills.head(2)
# Out:
#                                                    title    year  color  \
# director_name
# James Cameron                                     Avatar  2009.0  Color
# Gore Verbinski  Pirates of the Caribbean: At World's End  2007.0  Color
#
#                content_rating  duration  director_fb       actor1  actor1_fb  \
# director_name
# James Cameron           PG-13     178.0          0.0  CCH Pounder     1000.0
# Gore Verbinski          PG-13     169.0        563.0  Johnny Depp    40000.0
#
#                           actor2  actor2_fb          actor3  actor3_fb  \
# director_name
# James Cameron   Joel David Moore      936.0       Wes Studi      855.0
# Gore Verbinski     Orlando Bloom     5000.0  Jack Davenport     1000.0
#
#                       gross                           genres  num_reviews  \
# director_name
# James Cameron   760505847.0  Action|Adventure|Fantasy|Sci-Fi        723.0
# Gore Verbinski  309404152.0         Action|Adventure|Fantasy        302.0
#
# ...

# %%
# Try out resetting everything
pd.reset_option('all')
# Out:
# : boolean
#     use_inf_as_null had been deprecated and will be removed in a future
#     version. Use `use_inf_as_na` instead.
# C:\Users\jpkee\anaconda3\lib\site-packages\pandas\_config\config.py:620: FutureWarning:
# : boolean
#     use_inf_as_null had been deprecated and will be removed in a future
#     version. Use `use_inf_as_na` instead.
#
#   warnings.warn(d.msg, FutureWarning)

# %%
movieData
# Out:
#                                               year  color content_rating  \
# title
# Avatar                                      2009.0  Color          PG-13
# Pirates of the Caribbean: At World's End    2007.0  Color          PG-13
# Spectre                                     2015.0  Color          PG-13
# The Dark Knight Rises                       2012.0  Color          PG-13
# Star Wars: Episode VII - The Force Awakens     NaN    NaN            NaN
# ...                                            ...    ...            ...
# Signed Sealed Delivered                     2013.0  Color            NaN
# The Following                                  NaN  Color          TV-14
# A Plague So Pleasant                        2013.0  Color            NaN
# Shanghai Calling                            2012.0  Color          PG-13
# My Date with Drew                           2004.0  Color             PG
#
#                                             duration      director_name  \
# title
# ...

# %%
# Now reviewing the basics of data exploration
# https://www.udemy.com/course/master-data-analysis-with-python-intro-to-pandas/learn/lecture/13947888#overview

# %% [markdown]
#  ***5 Step Process for Data Exploration:***
#  1. Keep Jupyter notebook code simple
#      1. one line or so per cell for tidiness
#  2. Verify each line works as expected by verifying output
#  3. Assign the result of step 2 above to a variable
#  4. Output the head of the df or series
#  5. Continue to the next cell

# %%
import pandas as pd

# %%
#one line and verify
pd.read_csv('C:/Users/jpkee/Desktop/PythonProjects/Master Data Analysis with Python - Intro to pandas/data/bikes.csv')
# Out:
#         trip_id    usertype  gender            starttime             stoptime  \
# 0          7147  Subscriber    Male  2013-06-28 19:01:00  2013-06-28 19:17:00
# 1          7524  Subscriber    Male  2013-06-28 22:53:00  2013-06-28 23:03:00
# 2         10927  Subscriber    Male  2013-06-30 14:43:00  2013-06-30 15:01:00
# 3         12907  Subscriber    Male  2013-07-01 10:05:00  2013-07-01 10:16:00
# 4         13168  Subscriber    Male  2013-07-01 11:16:00  2013-07-01 11:18:00
# ...         ...         ...     ...                  ...                  ...
# 50084  17534938  Subscriber    Male  2017-12-30 13:07:00  2017-12-30 13:34:00
# 50085  17534969  Subscriber    Male  2017-12-30 13:34:00  2017-12-30 13:44:00
# 50086  17534972  Subscriber    Male  2017-12-30 13:34:00  2017-12-30 13:48:00
# 50087  17535645  Subscriber  Female  2017-12-31 09:30:00  2017-12-31 09:33:00
# 50088  17536246  Subscriber    Male  2017-12-31 15:22:00  2017-12-31 15:26:00
#
# ...

# %%
# output the head
bikes.head()
# Out:
#    trip_id    usertype gender            starttime             stoptime  \
# 0     7147  Subscriber   Male  2013-06-28 19:01:00  2013-06-28 19:17:00
# 1     7524  Subscriber   Male  2013-06-28 22:53:00  2013-06-28 23:03:00
# 2    10927  Subscriber   Male  2013-06-30 14:43:00  2013-06-30 15:01:00
# 3    12907  Subscriber   Male  2013-07-01 10:05:00  2013-07-01 10:16:00
# 4    13168  Subscriber   Male  2013-07-01 11:16:00  2013-07-01 11:18:00
#
#    tripduration             from_station_name  latitude_start  \
# 0           993     Lake Shore Dr & Monroe St       41.881050
# 1           623  Clinton St & Washington Blvd       41.883380
# 2          1040  Sheffield Ave & Kingsbury St       41.909592
# 3           667       Carpenter St & Huron St       41.894556
# 4           130        Damen Ave & Pierce Ave       41.909396
#
#    longitude_start  dpcapacity_start          to_station_name  latitude_end  \
# 0       -87.616970              11.0    Michigan Ave & Oak St     41.900960
# ...

# %%
import pandas as pd

# 'C:/Users/jpkee/Desktop/PythonProjects/Master Data Analysis with Python - Intro to pandas/data/bikes.csv')
petals = pd.read_csv('C:/Users/jpkee/Documents/My Tableau Repository/Datasources/irisData.csv')
petals.head()
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# an example with iris data
# file lives here: C:\Users\jpkee\Documents\My Tableau Repository\Datasources

# %%
petals.describe()
# Out:
#        Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
import bpy
import csv
import urllib.request

url_str = 'http://blender.chrisconlan.com/iris.csv'
iris_csv = urllib.request.urlopen(url_str)
# Read it into a csv iterator
iris_ob = csv.reader(iris_csv.read().decode('utf-8').splitlines())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ModuleNotFoundError: No module named 'bpy_types'
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ModuleNotFoundError: No module named 'bpy_types'
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ModuleNotFoundError: No module named 'bpy_types'
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ModuleNotFoundError: No module named 'bpy_types'
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ...

# %%
iris_header = []
iris_data = []

# %%
for v in iris_ob:
    if not iris_header:
        iris_header = v
    else:
        v = [float(v[0]),
             float(v[1]),
             float(v[2]),
             float(v[3]),
             str(v[4])]
        iris_data.append(v)
        
for i in range(len(iris_data)):
# Create a sphere at the origin
bpy.ops.mesh.primitive_uv_sphere_add(location=(0,0,0))

# Name it 'row-i'
bpy.context.object.name = 'row-' + str(i)

v = iris_data[i]
# Resize with an an arbitrary but more aesthetic value
bpy.ops.transform.resize(value=(0.15, 0.15, 0.15))

# Move the sphere to the correct position in 3D
bpy.ops.transform.translate(value=(v[0], v[1], v[2]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-62f6ebed5bcc> in <module>
#      13
#      14     # Create a sphere at the origin
# ---> 15     bpy.ops.mesh.primitive_uv_sphere_add(location=(0,0,0))
#      16
#      17     # Name it 'row-i'
#
# NameError: name 'bpy' is not defined
